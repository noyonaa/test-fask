# %%
import pyodbc
import pandas as pd
import csv

# %%
conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=cmdaserver.database.windows.net;"
    "DATABASE=CMDACopy;"
    "UID=CMDAUser;"
    "PWD=FarmiAnalysis123!;"
)
cursor = conn.cursor()

# %%
cursor.execute("""SELECT temp_farm_crop_baseline.*, t_user.company_id FROM temp_farm_crop_baseline 
               inner join t_farm on temp_farm_crop_baseline.farm_id = t_farm.farm_id
               inner join t_user on t_farm.user_id = t_user.user_id
               """)

column_names = [description[0] for description in cursor.description]

# Print the headers
print(','.join(column_names))

# Fetch and print each row
for row in cursor:
    print(','.join(map(str, row)))
# Out:
# farm_id,crop_id,crop_area,land_preparation_cost,planting_material_cost,labour_cost,fertilizer_cost,pest_disease_cost,other_cost,total_cost,total_yield,yield_quality,total_revenue,net_profit,baseline,company_id
# 126,354,0.50,4000.00,2000.00,2000.00,2500.00,2500.00,0.00,13000.00,1300.00,90.00,26000.00,13000.00,Y,1000
# 126,354,0.50,2500.00,2000.00,2500.00,3000.00,2500.00,0.00,12500.00,1000.00,90.00,30000.00,17500.00,N,1000
# 444,354,0.50,4000.00,4000.00,10000.00,9000.00,8000.00,4000.00,39000.00,4000.00,90.00,160000.00,121000.00,Y,1000
# 444,354,0.50,6000.00,5000.00,7000.00,4000.00,4000.00,0.00,26000.00,2000.00,85.00,70000.00,44000.00,N,1000
# 529,229,0.25,3000.00,4800.00,5000.00,3800.00,3600.00,0.00,20200.00,3500.00,80.00,48000.00,27800.00,Y,1000
# 529,229,0.25,6000.00,1500.00,1500.00,10000.00,5000.00,0.00,24000.00,18000.00,90.00,288000.00,264000.00,N,1000
# 543,358,1.00,3500.00,2800.00,4500.00,3800.00,2300.00,0.00,16900.00,1750.00,85.00,125000.00,108100.00,Y,1000
# ...

# %%
cursor.execute('SELECT * FROM v_act_obs')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'act_obs.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='',encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_plan_activity_stage')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'plan_acts_dates.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='',encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM temp_weather')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'weather.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='',encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_abnd_acts_name')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'act_abnd.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding= 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_weightage_fo')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'weightage.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute("""SELECT temp_farm_crop_baseline.*,t_farm.farm_name, t_user.company_id FROM temp_farm_crop_baseline 
               inner join t_farm on temp_farm_crop_baseline.farm_id = t_farm.farm_id
               inner join t_user on t_farm.user_id = t_user.user_id
               """)

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'baseline_YN.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_cmpl_acts_name')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'act_cmpl.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_activity_status_by_name')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'all_activityplans_byName.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_plans_by_fo')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'plans_by_FO_companies.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_yield_area_data')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'yield_totalArea.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_crop_plan_compliance')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'compliance.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_farm_basic_info')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'farms2.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT * FROM v_plan_wise_acts')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'plan_wise_activities.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)

# %%
cursor.execute('SELECT company_id, company_name FROM t_company')

# Fetch column names from cursor description
column_names = [description[0] for description in cursor.description]

# Define the CSV file path
csv_file_path = 'companies.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='', encoding = 'utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    
    # Write the column headers
    csv_writer.writerow(column_names)
    
    # Fetch and write each row
    for row in cursor:
        csv_writer.writerow(row)
